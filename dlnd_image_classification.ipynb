# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = 'cifar-10-python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 5
sample_id = 4
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 4:
# Image - Min Value: 2 Max Value: 248
# Image - Shape: (32, 32, 3)
# Label - Label Id: 5 Name: dog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    
    # using min-max scaling, we adjust the a and b values
    a = 0
    b = 1
    grayscale_min = 0
    grayscale_max = 255
    return a + ( ( (x - grayscale_min)*(b - a) )/( grayscale_max - grayscale_min ) )
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
# from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import label_binarize

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    
    # below is one way to one hot encode but doesnt pass the test
    '''
    encoder = LabelBinarizer()
    encoder.fit(x)
    encodings = encoder.transform(x)
    return encodings
    '''
    
    # so instead use 
    encodings = label_binarize(x, classes=np.arange(10))
    return encodings



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

## naming the placeholder within the TF placeholder function!!

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    x = tf.placeholder(tf.float32, (None, image_shape[0], image_shape[1], image_shape[2]),name = 'x')
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    y = tf.placeholder(tf.int32, [None,n_classes],name = 'y')
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    keep_prob = tf.placeholder(tf.float32, name = 'keep_prob')
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    
    # 2D tuple is somethings like (2,2)
    
    #### get tensorflow dimension as x_tensor value is (tf.placeholder(tf.float32, [None, 32, 32, 5]))
    color_channels = x_tensor.get_shape().as_list()[3]
    W = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], color_channels, conv_num_outputs]))
    
    strides = [1,conv_strides[0],conv_strides[1],1]
    
    ## add bias and non linear activation
    conv1_b = tf.Variable(tf.zeros(conv_num_outputs))
    # below is by getting the formula
    conv1   = tf.nn.conv2d(x_tensor, W, strides=strides, padding='SAME') + conv1_b
    conv1 = tf.nn.relu(conv1)
    
    ## now for max pooling layer
    pool_ksize = [1,pool_ksize[0],pool_ksize[1],1]
    max_strides = [1,pool_strides[0],pool_strides[1],1]
    
    
    conv1 = tf.nn.max_pool(conv1, pool_ksize, max_strides, padding='SAME')
    return conv1


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    
    # by doing below, u get [None, 5,2,3]
    shape = x_tensor.get_shape().as_list()
    
    
    # to flatten to get to 2d
    # see explanation here:
    # https://discussions.udacity.com/t/shape-when-flattening-the-tensor-from-4d-to-2d/225217/2
    
    fc1 = tf.reshape(x_tensor, [-1, shape[1]* shape[2] *shape[3]])
    return fc1


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    # layer packaging from tensorflow at https://www.tensorflow.org/api_docs/python/tf/contrib/layers/fully_connected
    # understand at https://discussions.udacity.com/t/difference-between-fcl-and-output-layer-in-cnn/225620/8
    # it will automatically create the weights and bias if the data is not fed
    return tf.contrib.layers.fully_connected(inputs=x_tensor, num_outputs=num_outputs)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    # suppose to let activation = none in the tf layer
    return tf.contrib.layers.fully_connected(inputs=x_tensor, num_outputs=num_outputs, activation_fn = None)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    # SOLUTION: Layer 1: Convolutional. Input = 32x32x3. Output = 28x28x6.
    # below is 5 x 5 filter of input depth of 3 and output depth of 6
    
    conv_ksize = (8,8)
    # by reducing stride value, longer to train
    conv_strides = (2, 2)
    pool_ksize = (4, 4)
    pool_strides = (4, 4)
    conv_num_outputs = 16
    
    
    conv1 = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    conv1 = flatten(conv1)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    conv1 = fully_conn(conv1, 192)
    conv1 = tf.nn.dropout(conv1, keep_prob)
    
    ## 2nd layer
    conv2 = fully_conn(conv1, 96)
    conv2 = tf.nn.dropout(conv2, keep_prob)
    
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Decensor, num_outputs)
    
    conv3 = output(conv2, 10)
    
    # TODO: return output
    return conv3


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict = {x : feature_batch, y : label_batch , keep_prob : keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    
    loss = session.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.})
    valid_acc = sess.run(accuracy, feed_dict={x: valid_features,y: valid_labels, keep_prob: 1.})
    
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(loss,valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 256
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2914 Validation Accuracy: 0.157800
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.2613 Validation Accuracy: 0.167400
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.2397 Validation Accuracy: 0.231600
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.1862 Validation Accuracy: 0.237400
# Epoch  5, CIFAR-10 Batch 1:  Loss:     2.1503 Validation Accuracy: 0.258000
# Epoch  6, CIFAR-10 Batch 1:  Loss:     2.1368 Validation Accuracy: 0.269000
# Epoch  7, CIFAR-10 Batch 1:  Loss:     2.1198 Validation Accuracy: 0.271200
# Epoch  8, CIFAR-10 Batch 1:  Loss:     2.0812 Validation Accuracy: 0.293200
# Epoch  9, CIFAR-10 Batch 1:  Loss:     2.0674 Validation Accuracy: 0.290000
# Epoch 10, CIFAR-10 Batch 1:  Loss:     2.0684 Validation Accuracy: 0.296200
# Epoch 11, CIFAR-10 Batch 1:  Loss:     2.0234 Validation Accuracy: 0.310600
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.9905 Validation Accuracy: 0.314200
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.9559 Validation Accuracy: 0.322800
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.9561 Validation Accuracy: 0.308600
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.9001 Validation Accuracy: 0.340200
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.8635 Validation Accuracy: 0.355800
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.8228 Validation Accuracy: 0.356600
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.7712 Validation Accuracy: 0.355800
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.7832 Validation Accuracy: 0.378000
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.7167 Validation Accuracy: 0.384000
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.7038 Validation Accuracy: 0.370800
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.6747 Validation Accuracy: 0.392400
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.6762 Validation Accuracy: 0.389400
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.6894 Validation Accuracy: 0.392400
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.5857 Validation Accuracy: 0.402600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.5910 Validation Accuracy: 0.404000
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.5594 Validation Accuracy: 0.406600
# Epoch 28, CIFAR-10 Batch 1:  Loss:     1.5526 Validation Accuracy: 0.419000
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.5124 Validation Accuracy: 0.424000
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.5335 Validation Accuracy: 0.427000
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.4769 Validation Accuracy: 0.432600
# Epoch 32, CIFAR-10 Batch 1:  Loss:     1.4379 Validation Accuracy: 0.430200
# Epoch 33, CIFAR-10 Batch 1:  Loss:     1.4732 Validation Accuracy: 0.436200
# Epoch 34, CIFAR-10 Batch 1:  Loss:     1.3859 Validation Accuracy: 0.439600
# Epoch 35, CIFAR-10 Batch 1:  Loss:     1.3356 Validation Accuracy: 0.444600
# Epoch 36, CIFAR-10 Batch 1:  Loss:     1.3396 Validation Accuracy: 0.438800
# Epoch 37, CIFAR-10 Batch 1:  Loss:     1.3168 Validation Accuracy: 0.449600
# Epoch 38, CIFAR-10 Batch 1:  Loss:     1.3014 Validation Accuracy: 0.429000
# Epoch 39, CIFAR-10 Batch 1:  Loss:     1.2846 Validation Accuracy: 0.457600
# Epoch 40, CIFAR-10 Batch 1:  Loss:     1.2734 Validation Accuracy: 0.445800
# Epoch 41, CIFAR-10 Batch 1:  Loss:     1.2497 Validation Accuracy: 0.454200
# Epoch 42, CIFAR-10 Batch 1:  Loss:     1.2225 Validation Accuracy: 0.447600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     1.2408 Validation Accuracy: 0.460800
# Epoch 44, CIFAR-10 Batch 1:  Loss:     1.1791 Validation Accuracy: 0.457600
# Epoch 45, CIFAR-10 Batch 1:  Loss:     1.1808 Validation Accuracy: 0.452800
# Epoch 46, CIFAR-10 Batch 1:  Loss:     1.1625 Validation Accuracy: 0.465600
# Epoch 47, CIFAR-10 Batch 1:  Loss:     1.1487 Validation Accuracy: 0.466400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     1.1235 Validation Accuracy: 0.463000
# Epoch 49, CIFAR-10 Batch 1:  Loss:     1.1084 Validation Accuracy: 0.468800
# Epoch 50, CIFAR-10 Batch 1:  Loss:     1.0735 Validation Accuracy: 0.467600
# Epoch 51, CIFAR-10 Batch 1:  Loss:     1.0697 Validation Accuracy: 0.474600
# Epoch 52, CIFAR-10 Batch 1:  Loss:     1.0865 Validation Accuracy: 0.470400
# Epoch 53, CIFAR-10 Batch 1:  Loss:     1.0339 Validation Accuracy: 0.470000
# Epoch 54, CIFAR-10 Batch 1:  Loss:     1.0307 Validation Accuracy: 0.474800
# Epoch 55, CIFAR-10 Batch 1:  Loss:     1.0344 Validation Accuracy: 0.480000
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.9682 Validation Accuracy: 0.480800
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.9853 Validation Accuracy: 0.476000
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.9436 Validation Accuracy: 0.480600
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.9638 Validation Accuracy: 0.481200
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.9440 Validation Accuracy: 0.482400
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.8928 Validation Accuracy: 0.484000
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.8915 Validation Accuracy: 0.486000
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.9054 Validation Accuracy: 0.487000
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.8755 Validation Accuracy: 0.485400
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.8394 Validation Accuracy: 0.483000
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.8231 Validation Accuracy: 0.484600
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.8252 Validation Accuracy: 0.492400
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.8312 Validation Accuracy: 0.486200
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.8125 Validation Accuracy: 0.483600
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.7901 Validation Accuracy: 0.488800
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.8103 Validation Accuracy: 0.494800
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.7699 Validation Accuracy: 0.493600
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.7680 Validation Accuracy: 0.493400
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.7297 Validation Accuracy: 0.493000
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.7384 Validation Accuracy: 0.491000
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.7392 Validation Accuracy: 0.491600
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.7313 Validation Accuracy: 0.491600
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.7186 Validation Accuracy: 0.498000
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.6924 Validation Accuracy: 0.498000
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.7147 Validation Accuracy: 0.503800
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.6886 Validation Accuracy: 0.499200
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.7119 Validation Accuracy: 0.499800
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.6709 Validation Accuracy: 0.503000
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.6356 Validation Accuracy: 0.494200
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.6539 Validation Accuracy: 0.500000
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.6421 Validation Accuracy: 0.491200
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.6347 Validation Accuracy: 0.502800
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.5934 Validation Accuracy: 0.499000
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.6324 Validation Accuracy: 0.498400
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.6124 Validation Accuracy: 0.502200
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.6189 Validation Accuracy: 0.499000
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.6117 Validation Accuracy: 0.499400
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.6040 Validation Accuracy: 0.506600
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.6007 Validation Accuracy: 0.497600
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.5564 Validation Accuracy: 0.500600
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.5719 Validation Accuracy: 0.505800
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.5697 Validation Accuracy: 0.509800
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.5835 Validation Accuracy: 0.502400
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.5650 Validation Accuracy: 0.506400
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.5830 Validation Accuracy: 0.507600

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2309 Validation Accuracy: 0.187000
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.2640 Validation Accuracy: 0.201000
# Epoch  1, CIFAR-10 Batch 3:  Loss:     2.0868 Validation Accuracy: 0.230600
# Epoch  1, CIFAR-10 Batch 4:  Loss:     2.0627 Validation Accuracy: 0.246000
# Epoch  1, CIFAR-10 Batch 5:  Loss:     2.0370 Validation Accuracy: 0.283000
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.0715 Validation Accuracy: 0.296200
# Epoch  2, CIFAR-10 Batch 2:  Loss:     2.0331 Validation Accuracy: 0.299000
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.7949 Validation Accuracy: 0.326800
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.8310 Validation Accuracy: 0.344600
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.8206 Validation Accuracy: 0.342400
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.9955 Validation Accuracy: 0.358000
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.8980 Validation Accuracy: 0.350400
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.7101 Validation Accuracy: 0.377600
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.7024 Validation Accuracy: 0.371600
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.7223 Validation Accuracy: 0.371000
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.9166 Validation Accuracy: 0.380200
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.8822 Validation Accuracy: 0.394200
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.5476 Validation Accuracy: 0.404200
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.6488 Validation Accuracy: 0.405800
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.6461 Validation Accuracy: 0.403400
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.8622 Validation Accuracy: 0.413000
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.7635 Validation Accuracy: 0.418000
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.5062 Validation Accuracy: 0.415200
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.5628 Validation Accuracy: 0.426200
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.6582 Validation Accuracy: 0.417400
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.7302 Validation Accuracy: 0.425400
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.6199 Validation Accuracy: 0.425000
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.4893 Validation Accuracy: 0.437800
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.5166 Validation Accuracy: 0.439800
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.5759 Validation Accuracy: 0.433600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.6988 Validation Accuracy: 0.440800
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.5875 Validation Accuracy: 0.441400
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.4322 Validation Accuracy: 0.441400
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.4677 Validation Accuracy: 0.449400
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.5525 Validation Accuracy: 0.449200
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.6005 Validation Accuracy: 0.449400
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.4799 Validation Accuracy: 0.448800
# Epoch  8, CIFAR-10 Batch 3:  Loss:     1.4217 Validation Accuracy: 0.453200
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.4293 Validation Accuracy: 0.469600
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.5113 Validation Accuracy: 0.459600
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.5582 Validation Accuracy: 0.464000
# Epoch  9, CIFAR-10 Batch 2:  Loss:     1.4490 Validation Accuracy: 0.458000
# Epoch  9, CIFAR-10 Batch 3:  Loss:     1.3743 Validation Accuracy: 0.466400
# Epoch  9, CIFAR-10 Batch 4:  Loss:     1.3952 Validation Accuracy: 0.470000
# Epoch  9, CIFAR-10 Batch 5:  Loss:     1.4832 Validation Accuracy: 0.462600
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.4977 Validation Accuracy: 0.470800
# Epoch 10, CIFAR-10 Batch 2:  Loss:     1.3878 Validation Accuracy: 0.471600
# Epoch 10, CIFAR-10 Batch 3:  Loss:     1.3250 Validation Accuracy: 0.467400
# Epoch 10, CIFAR-10 Batch 4:  Loss:     1.3658 Validation Accuracy: 0.467600
# Epoch 10, CIFAR-10 Batch 5:  Loss:     1.4422 Validation Accuracy: 0.471200
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.4774 Validation Accuracy: 0.467400
# Epoch 11, CIFAR-10 Batch 2:  Loss:     1.3678 Validation Accuracy: 0.475400
# Epoch 11, CIFAR-10 Batch 3:  Loss:     1.3156 Validation Accuracy: 0.473800
# Epoch 11, CIFAR-10 Batch 4:  Loss:     1.3580 Validation Accuracy: 0.474400
# Epoch 11, CIFAR-10 Batch 5:  Loss:     1.4180 Validation Accuracy: 0.468200
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.4649 Validation Accuracy: 0.471200
# Epoch 12, CIFAR-10 Batch 2:  Loss:     1.3529 Validation Accuracy: 0.474800
# Epoch 12, CIFAR-10 Batch 3:  Loss:     1.2886 Validation Accuracy: 0.476000
# Epoch 12, CIFAR-10 Batch 4:  Loss:     1.3212 Validation Accuracy: 0.476200
# Epoch 12, CIFAR-10 Batch 5:  Loss:     1.3713 Validation Accuracy: 0.483000
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.3998 Validation Accuracy: 0.477400
# Epoch 13, CIFAR-10 Batch 2:  Loss:     1.3529 Validation Accuracy: 0.493800
# Epoch 13, CIFAR-10 Batch 3:  Loss:     1.2649 Validation Accuracy: 0.480400
# Epoch 13, CIFAR-10 Batch 4:  Loss:     1.3160 Validation Accuracy: 0.487000
# Epoch 13, CIFAR-10 Batch 5:  Loss:     1.3667 Validation Accuracy: 0.488600
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.3692 Validation Accuracy: 0.490800
# Epoch 14, CIFAR-10 Batch 2:  Loss:     1.3510 Validation Accuracy: 0.495200
# Epoch 14, CIFAR-10 Batch 3:  Loss:     1.2136 Validation Accuracy: 0.491200
# Epoch 14, CIFAR-10 Batch 4:  Loss:     1.2620 Validation Accuracy: 0.490400
# Epoch 14, CIFAR-10 Batch 5:  Loss:     1.3457 Validation Accuracy: 0.489800
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.3791 Validation Accuracy: 0.488400
# Epoch 15, CIFAR-10 Batch 2:  Loss:     1.2764 Validation Accuracy: 0.491400
# Epoch 15, CIFAR-10 Batch 3:  Loss:     1.1866 Validation Accuracy: 0.493800
# Epoch 15, CIFAR-10 Batch 4:  Loss:     1.2654 Validation Accuracy: 0.490800
# Epoch 15, CIFAR-10 Batch 5:  Loss:     1.3163 Validation Accuracy: 0.496400
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.3596 Validation Accuracy: 0.487800
# Epoch 16, CIFAR-10 Batch 2:  Loss:     1.2424 Validation Accuracy: 0.495400
# Epoch 16, CIFAR-10 Batch 3:  Loss:     1.1433 Validation Accuracy: 0.496600
# Epoch 16, CIFAR-10 Batch 4:  Loss:     1.2579 Validation Accuracy: 0.496800
# Epoch 16, CIFAR-10 Batch 5:  Loss:     1.2649 Validation Accuracy: 0.497800
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.3242 Validation Accuracy: 0.499800
# Epoch 17, CIFAR-10 Batch 2:  Loss:     1.2745 Validation Accuracy: 0.511400
# Epoch 17, CIFAR-10 Batch 3:  Loss:     1.1450 Validation Accuracy: 0.497600
# Epoch 17, CIFAR-10 Batch 4:  Loss:     1.2159 Validation Accuracy: 0.506400
# Epoch 17, CIFAR-10 Batch 5:  Loss:     1.2844 Validation Accuracy: 0.500600
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.3064 Validation Accuracy: 0.501200
# Epoch 18, CIFAR-10 Batch 2:  Loss:     1.2926 Validation Accuracy: 0.504200
# Epoch 18, CIFAR-10 Batch 3:  Loss:     1.0803 Validation Accuracy: 0.511000
# Epoch 18, CIFAR-10 Batch 4:  Loss:     1.1797 Validation Accuracy: 0.495600
# Epoch 18, CIFAR-10 Batch 5:  Loss:     1.2518 Validation Accuracy: 0.505400
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.2861 Validation Accuracy: 0.495800
# Epoch 19, CIFAR-10 Batch 2:  Loss:     1.2648 Validation Accuracy: 0.510600
# Epoch 19, CIFAR-10 Batch 3:  Loss:     1.0917 Validation Accuracy: 0.515600
# Epoch 19, CIFAR-10 Batch 4:  Loss:     1.1639 Validation Accuracy: 0.507200
# Epoch 19, CIFAR-10 Batch 5:  Loss:     1.1984 Validation Accuracy: 0.509800
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.2485 Validation Accuracy: 0.505200
# Epoch 20, CIFAR-10 Batch 2:  Loss:     1.2178 Validation Accuracy: 0.513400
# Epoch 20, CIFAR-10 Batch 3:  Loss:     1.0783 Validation Accuracy: 0.512600
# Epoch 20, CIFAR-10 Batch 4:  Loss:     1.1545 Validation Accuracy: 0.518600
# Epoch 20, CIFAR-10 Batch 5:  Loss:     1.1930 Validation Accuracy: 0.515400
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.2334 Validation Accuracy: 0.517600
# Epoch 21, CIFAR-10 Batch 2:  Loss:     1.2298 Validation Accuracy: 0.506000
# Epoch 21, CIFAR-10 Batch 3:  Loss:     1.0666 Validation Accuracy: 0.514800
# Epoch 21, CIFAR-10 Batch 4:  Loss:     1.1215 Validation Accuracy: 0.514200
# Epoch 21, CIFAR-10 Batch 5:  Loss:     1.1980 Validation Accuracy: 0.513400
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.2169 Validation Accuracy: 0.513200
# Epoch 22, CIFAR-10 Batch 2:  Loss:     1.2094 Validation Accuracy: 0.510400
# Epoch 22, CIFAR-10 Batch 3:  Loss:     1.0615 Validation Accuracy: 0.513600
# Epoch 22, CIFAR-10 Batch 4:  Loss:     1.1008 Validation Accuracy: 0.525600
# Epoch 22, CIFAR-10 Batch 5:  Loss:     1.2058 Validation Accuracy: 0.511000
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.1907 Validation Accuracy: 0.518600
# Epoch 23, CIFAR-10 Batch 2:  Loss:     1.1891 Validation Accuracy: 0.520000
# Epoch 23, CIFAR-10 Batch 3:  Loss:     1.0059 Validation Accuracy: 0.523000
# Epoch 23, CIFAR-10 Batch 4:  Loss:     1.0795 Validation Accuracy: 0.523800
# Epoch 23, CIFAR-10 Batch 5:  Loss:     1.1442 Validation Accuracy: 0.520600
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.1712 Validation Accuracy: 0.524800
# Epoch 24, CIFAR-10 Batch 2:  Loss:     1.1767 Validation Accuracy: 0.525400
# Epoch 24, CIFAR-10 Batch 3:  Loss:     1.0272 Validation Accuracy: 0.514200
# Epoch 24, CIFAR-10 Batch 4:  Loss:     1.0834 Validation Accuracy: 0.529800
# Epoch 24, CIFAR-10 Batch 5:  Loss:     1.1608 Validation Accuracy: 0.519800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.1566 Validation Accuracy: 0.532400
# Epoch 25, CIFAR-10 Batch 2:  Loss:     1.1658 Validation Accuracy: 0.526000
# Epoch 25, CIFAR-10 Batch 3:  Loss:     1.0078 Validation Accuracy: 0.527600
# Epoch 25, CIFAR-10 Batch 4:  Loss:     1.0707 Validation Accuracy: 0.523000
# Epoch 25, CIFAR-10 Batch 5:  Loss:     1.1347 Validation Accuracy: 0.527400
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.2182 Validation Accuracy: 0.524800
# Epoch 26, CIFAR-10 Batch 2:  Loss:     1.1462 Validation Accuracy: 0.530000
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.9713 Validation Accuracy: 0.529400
# Epoch 26, CIFAR-10 Batch 4:  Loss:     1.0402 Validation Accuracy: 0.529400
# Epoch 26, CIFAR-10 Batch 5:  Loss:     1.1242 Validation Accuracy: 0.518200
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.1719 Validation Accuracy: 0.531000
# Epoch 27, CIFAR-10 Batch 2:  Loss:     1.1177 Validation Accuracy: 0.525000
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.9601 Validation Accuracy: 0.534000
# Epoch 27, CIFAR-10 Batch 4:  Loss:     1.0362 Validation Accuracy: 0.535000
# Epoch 27, CIFAR-10 Batch 5:  Loss:     1.0981 Validation Accuracy: 0.533400
# Epoch 28, CIFAR-10 Batch 1:  Loss:     1.0997 Validation Accuracy: 0.535400
# Epoch 28, CIFAR-10 Batch 2:  Loss:     1.1344 Validation Accuracy: 0.536000
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.9760 Validation Accuracy: 0.531600
# Epoch 28, CIFAR-10 Batch 4:  Loss:     1.0226 Validation Accuracy: 0.535200
# Epoch 28, CIFAR-10 Batch 5:  Loss:     1.0882 Validation Accuracy: 0.531800
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.1596 Validation Accuracy: 0.538200
# Epoch 29, CIFAR-10 Batch 2:  Loss:     1.1284 Validation Accuracy: 0.539000
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.9424 Validation Accuracy: 0.535400
# Epoch 29, CIFAR-10 Batch 4:  Loss:     1.0071 Validation Accuracy: 0.534000
# Epoch 29, CIFAR-10 Batch 5:  Loss:     1.0966 Validation Accuracy: 0.524200
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.1066 Validation Accuracy: 0.543400
# Epoch 30, CIFAR-10 Batch 2:  Loss:     1.1229 Validation Accuracy: 0.535200
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.9452 Validation Accuracy: 0.541800
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.9793 Validation Accuracy: 0.531000
# Epoch 30, CIFAR-10 Batch 5:  Loss:     1.0751 Validation Accuracy: 0.532800
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.0855 Validation Accuracy: 0.538600
# Epoch 31, CIFAR-10 Batch 2:  Loss:     1.1195 Validation Accuracy: 0.542400
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.9626 Validation Accuracy: 0.547200
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.9883 Validation Accuracy: 0.548200
# Epoch 31, CIFAR-10 Batch 5:  Loss:     1.0713 Validation Accuracy: 0.521000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     1.1013 Validation Accuracy: 0.537400
# Epoch 32, CIFAR-10 Batch 2:  Loss:     1.1107 Validation Accuracy: 0.544800
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.9380 Validation Accuracy: 0.539000
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.9853 Validation Accuracy: 0.547000
# Epoch 32, CIFAR-10 Batch 5:  Loss:     1.0607 Validation Accuracy: 0.536200
# Epoch 33, CIFAR-10 Batch 1:  Loss:     1.0781 Validation Accuracy: 0.534200
# Epoch 33, CIFAR-10 Batch 2:  Loss:     1.0726 Validation Accuracy: 0.539000
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.9109 Validation Accuracy: 0.549800
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.9983 Validation Accuracy: 0.540800
# Epoch 33, CIFAR-10 Batch 5:  Loss:     1.0787 Validation Accuracy: 0.536600
# Epoch 34, CIFAR-10 Batch 1:  Loss:     1.0754 Validation Accuracy: 0.548200
# Epoch 34, CIFAR-10 Batch 2:  Loss:     1.0819 Validation Accuracy: 0.546200
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.9314 Validation Accuracy: 0.545200
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.9328 Validation Accuracy: 0.544600
# Epoch 34, CIFAR-10 Batch 5:  Loss:     1.0585 Validation Accuracy: 0.538000
# Epoch 35, CIFAR-10 Batch 1:  Loss:     1.0306 Validation Accuracy: 0.545000
# Epoch 35, CIFAR-10 Batch 2:  Loss:     1.0572 Validation Accuracy: 0.546800
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.9198 Validation Accuracy: 0.542600
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.9372 Validation Accuracy: 0.539400
# Epoch 35, CIFAR-10 Batch 5:  Loss:     1.0683 Validation Accuracy: 0.534400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     1.0311 Validation Accuracy: 0.552200
# Epoch 36, CIFAR-10 Batch 2:  Loss:     1.0461 Validation Accuracy: 0.546400
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.8894 Validation Accuracy: 0.547200
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.9704 Validation Accuracy: 0.549400
# Epoch 36, CIFAR-10 Batch 5:  Loss:     1.0332 Validation Accuracy: 0.541000
# Epoch 37, CIFAR-10 Batch 1:  Loss:     1.0251 Validation Accuracy: 0.551400
# Epoch 37, CIFAR-10 Batch 2:  Loss:     1.0303 Validation Accuracy: 0.551000
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.8811 Validation Accuracy: 0.543600
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.9037 Validation Accuracy: 0.541600
# Epoch 37, CIFAR-10 Batch 5:  Loss:     1.0538 Validation Accuracy: 0.553200
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.9932 Validation Accuracy: 0.552200
# Epoch 38, CIFAR-10 Batch 2:  Loss:     1.0131 Validation Accuracy: 0.554000
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.8773 Validation Accuracy: 0.545600
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.9050 Validation Accuracy: 0.549600
# Epoch 38, CIFAR-10 Batch 5:  Loss:     1.0668 Validation Accuracy: 0.541000
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.9679 Validation Accuracy: 0.551200
# Epoch 39, CIFAR-10 Batch 2:  Loss:     1.0440 Validation Accuracy: 0.547200
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.8620 Validation Accuracy: 0.547600
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.9009 Validation Accuracy: 0.553800
# Epoch 39, CIFAR-10 Batch 5:  Loss:     1.0437 Validation Accuracy: 0.535600
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.9604 Validation Accuracy: 0.557200
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.9799 Validation Accuracy: 0.550600
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.8652 Validation Accuracy: 0.550400
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.8937 Validation Accuracy: 0.545600
# Epoch 40, CIFAR-10 Batch 5:  Loss:     1.0195 Validation Accuracy: 0.545400
# Epoch 41, CIFAR-10 Batch 1:  Loss:     1.0281 Validation Accuracy: 0.548000
# Epoch 41, CIFAR-10 Batch 2:  Loss:     1.0084 Validation Accuracy: 0.551200
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.8720 Validation Accuracy: 0.553600
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.8801 Validation Accuracy: 0.548400
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.9772 Validation Accuracy: 0.545800
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.9462 Validation Accuracy: 0.548000
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.9882 Validation Accuracy: 0.550200
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.8890 Validation Accuracy: 0.550600
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.8574 Validation Accuracy: 0.554600
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.9790 Validation Accuracy: 0.552400
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.9527 Validation Accuracy: 0.554000
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.9876 Validation Accuracy: 0.545000
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.8844 Validation Accuracy: 0.555800
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.9032 Validation Accuracy: 0.556000
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.9659 Validation Accuracy: 0.550200
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.9144 Validation Accuracy: 0.559600
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.9864 Validation Accuracy: 0.556400
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.8358 Validation Accuracy: 0.556600
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.8738 Validation Accuracy: 0.545800
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.9721 Validation Accuracy: 0.549200
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.9594 Validation Accuracy: 0.558200
# Epoch 45, CIFAR-10 Batch 2:  Loss:     1.0004 Validation Accuracy: 0.557200
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.8266 Validation Accuracy: 0.554200
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.8569 Validation Accuracy: 0.556800
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.9469 Validation Accuracy: 0.544000
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.9366 Validation Accuracy: 0.562000
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.9871 Validation Accuracy: 0.561000
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.8103 Validation Accuracy: 0.562800
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.8611 Validation Accuracy: 0.557400
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.9443 Validation Accuracy: 0.552200
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.9316 Validation Accuracy: 0.557800
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.9534 Validation Accuracy: 0.559200
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.8279 Validation Accuracy: 0.555000
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.8483 Validation Accuracy: 0.555800
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.9093 Validation Accuracy: 0.548000
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.9540 Validation Accuracy: 0.558000
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.9397 Validation Accuracy: 0.555800
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.8246 Validation Accuracy: 0.554600
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.8415 Validation Accuracy: 0.561600
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.9289 Validation Accuracy: 0.541800
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.9115 Validation Accuracy: 0.565000
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.9602 Validation Accuracy: 0.549800
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.8199 Validation Accuracy: 0.553000
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.8385 Validation Accuracy: 0.560600
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.8840 Validation Accuracy: 0.551000
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.8866 Validation Accuracy: 0.562600
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.8896 Validation Accuracy: 0.553400
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.8149 Validation Accuracy: 0.559400
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.8035 Validation Accuracy: 0.556600
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.8931 Validation Accuracy: 0.559600
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.9410 Validation Accuracy: 0.563400
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.9361 Validation Accuracy: 0.567200
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.8292 Validation Accuracy: 0.560600
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.8330 Validation Accuracy: 0.563000
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.9289 Validation Accuracy: 0.551200
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.8972 Validation Accuracy: 0.561600
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.9496 Validation Accuracy: 0.559400
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.7945 Validation Accuracy: 0.558600
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.8109 Validation Accuracy: 0.562000
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.9417 Validation Accuracy: 0.552800
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.9109 Validation Accuracy: 0.566800
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.9135 Validation Accuracy: 0.566600
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.8282 Validation Accuracy: 0.554600
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.7930 Validation Accuracy: 0.565600
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.9133 Validation Accuracy: 0.549800
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.8778 Validation Accuracy: 0.564000
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.9000 Validation Accuracy: 0.567800
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.8051 Validation Accuracy: 0.554000
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.7990 Validation Accuracy: 0.560600
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.9473 Validation Accuracy: 0.556200
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.9269 Validation Accuracy: 0.563200
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.9189 Validation Accuracy: 0.556000
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.7804 Validation Accuracy: 0.559000
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.8174 Validation Accuracy: 0.557800
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.9284 Validation Accuracy: 0.554800
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.8886 Validation Accuracy: 0.566200
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.8958 Validation Accuracy: 0.559800
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.7692 Validation Accuracy: 0.565000
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.7872 Validation Accuracy: 0.559600
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.9440 Validation Accuracy: 0.548800
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.8686 Validation Accuracy: 0.569800
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.8811 Validation Accuracy: 0.563200
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.7915 Validation Accuracy: 0.560600
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.7899 Validation Accuracy: 0.563000
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.8996 Validation Accuracy: 0.569400
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.8987 Validation Accuracy: 0.565400
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.8868 Validation Accuracy: 0.562000
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.7701 Validation Accuracy: 0.564000
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.7829 Validation Accuracy: 0.567200
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.9281 Validation Accuracy: 0.557800
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.9049 Validation Accuracy: 0.564800
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.9135 Validation Accuracy: 0.561200
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.7719 Validation Accuracy: 0.565000
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.7736 Validation Accuracy: 0.564200
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.9420 Validation Accuracy: 0.554200
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.8583 Validation Accuracy: 0.564000
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.9014 Validation Accuracy: 0.566600
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.7932 Validation Accuracy: 0.565800
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.7895 Validation Accuracy: 0.561200
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.8877 Validation Accuracy: 0.560000
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.8530 Validation Accuracy: 0.563600
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.9163 Validation Accuracy: 0.558000
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.7834 Validation Accuracy: 0.562800
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.7933 Validation Accuracy: 0.556600
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.9061 Validation Accuracy: 0.558600
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.8559 Validation Accuracy: 0.571800
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.8622 Validation Accuracy: 0.563600
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.7550 Validation Accuracy: 0.562400
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.8054 Validation Accuracy: 0.569400
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.8943 Validation Accuracy: 0.565600
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.8187 Validation Accuracy: 0.566600
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.8946 Validation Accuracy: 0.566600
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.7628 Validation Accuracy: 0.563600
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.7997 Validation Accuracy: 0.564800
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.8995 Validation Accuracy: 0.556400
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.8162 Validation Accuracy: 0.566600
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.8570 Validation Accuracy: 0.569200
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.7485 Validation Accuracy: 0.569000
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.7991 Validation Accuracy: 0.569600
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.8873 Validation Accuracy: 0.563200
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.8395 Validation Accuracy: 0.568800
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.8846 Validation Accuracy: 0.563000
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.7632 Validation Accuracy: 0.570400
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.7890 Validation Accuracy: 0.567200
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.8909 Validation Accuracy: 0.566000
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.8388 Validation Accuracy: 0.574200
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.8527 Validation Accuracy: 0.567000
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.7451 Validation Accuracy: 0.563200
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.7647 Validation Accuracy: 0.567600
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.9251 Validation Accuracy: 0.563200
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.8432 Validation Accuracy: 0.569600
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.8501 Validation Accuracy: 0.564200
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.7546 Validation Accuracy: 0.565600
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.7684 Validation Accuracy: 0.571000
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.8734 Validation Accuracy: 0.566200
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.8142 Validation Accuracy: 0.574400
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.8709 Validation Accuracy: 0.567400
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.7380 Validation Accuracy: 0.571600
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.7663 Validation Accuracy: 0.570200
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.8473 Validation Accuracy: 0.570600
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.8342 Validation Accuracy: 0.571000
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.8496 Validation Accuracy: 0.570800
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.7268 Validation Accuracy: 0.568400
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.7638 Validation Accuracy: 0.571200
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.8622 Validation Accuracy: 0.570000
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.7983 Validation Accuracy: 0.565800
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.8536 Validation Accuracy: 0.569000
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.7606 Validation Accuracy: 0.566400
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.7738 Validation Accuracy: 0.566000
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.8479 Validation Accuracy: 0.571200
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.8092 Validation Accuracy: 0.574200
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.8188 Validation Accuracy: 0.569800
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.7196 Validation Accuracy: 0.569600
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.7349 Validation Accuracy: 0.572400
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.8784 Validation Accuracy: 0.568600
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.8321 Validation Accuracy: 0.570400
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.8372 Validation Accuracy: 0.579000
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.7325 Validation Accuracy: 0.571400
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.7072 Validation Accuracy: 0.569600
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.8360 Validation Accuracy: 0.572600
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.8177 Validation Accuracy: 0.579000
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.7896 Validation Accuracy: 0.573400
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.7368 Validation Accuracy: 0.577200
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.7448 Validation Accuracy: 0.566800
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.8572 Validation Accuracy: 0.564000
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.8233 Validation Accuracy: 0.573400
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.8451 Validation Accuracy: 0.567800
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.7335 Validation Accuracy: 0.571400
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.7417 Validation Accuracy: 0.576200
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.8431 Validation Accuracy: 0.572800
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.8044 Validation Accuracy: 0.571800
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.8118 Validation Accuracy: 0.570800
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.7368 Validation Accuracy: 0.569800
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.7379 Validation Accuracy: 0.571200
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.8611 Validation Accuracy: 0.571200
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.7915 Validation Accuracy: 0.577600
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.8434 Validation Accuracy: 0.564000
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.7305 Validation Accuracy: 0.575200
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.7313 Validation Accuracy: 0.573200
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.8581 Validation Accuracy: 0.566400
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.7965 Validation Accuracy: 0.573400
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.8486 Validation Accuracy: 0.576600
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.7154 Validation Accuracy: 0.583800
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.7526 Validation Accuracy: 0.584600
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.8324 Validation Accuracy: 0.570000
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.7915 Validation Accuracy: 0.580200
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.8191 Validation Accuracy: 0.575000
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.7224 Validation Accuracy: 0.578200
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.7204 Validation Accuracy: 0.584000
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.8314 Validation Accuracy: 0.579000
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.7626 Validation Accuracy: 0.580000
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.8237 Validation Accuracy: 0.577000
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.7113 Validation Accuracy: 0.578800
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.7064 Validation Accuracy: 0.576600
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.8253 Validation Accuracy: 0.574800
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.7718 Validation Accuracy: 0.581600
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.8001 Validation Accuracy: 0.568600
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.7126 Validation Accuracy: 0.579400
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.7112 Validation Accuracy: 0.574800
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.8174 Validation Accuracy: 0.565800
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.7511 Validation Accuracy: 0.576600
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.8050 Validation Accuracy: 0.586400
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.6955 Validation Accuracy: 0.581400
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.7349 Validation Accuracy: 0.578400
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.8503 Validation Accuracy: 0.581400
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.7586 Validation Accuracy: 0.583200
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.7805 Validation Accuracy: 0.575800
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.7452 Validation Accuracy: 0.573400
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.7282 Validation Accuracy: 0.577600
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.8521 Validation Accuracy: 0.571400
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.7812 Validation Accuracy: 0.583200
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.8384 Validation Accuracy: 0.578400
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.7250 Validation Accuracy: 0.580200
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.7125 Validation Accuracy: 0.582400
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.8604 Validation Accuracy: 0.575400
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.7840 Validation Accuracy: 0.585000
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.8090 Validation Accuracy: 0.577800
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.7354 Validation Accuracy: 0.575200
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.6992 Validation Accuracy: 0.578600
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.8363 Validation Accuracy: 0.579400
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.7984 Validation Accuracy: 0.583200
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.7917 Validation Accuracy: 0.578800
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.7077 Validation Accuracy: 0.578200
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.7111 Validation Accuracy: 0.588800
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.8261 Validation Accuracy: 0.579800
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.8159 Validation Accuracy: 0.582800
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.8037 Validation Accuracy: 0.573800
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.6907 Validation Accuracy: 0.577600
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.6964 Validation Accuracy: 0.580600
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.8261 Validation Accuracy: 0.567400
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.7972 Validation Accuracy: 0.578800
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.7757 Validation Accuracy: 0.575600
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.7113 Validation Accuracy: 0.581600
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.6799 Validation Accuracy: 0.580600
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.7955 Validation Accuracy: 0.580200
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.7847 Validation Accuracy: 0.582600
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.7879 Validation Accuracy: 0.573400
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.7034 Validation Accuracy: 0.579200
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.6895 Validation Accuracy: 0.582600
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.7821 Validation Accuracy: 0.580800
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.7233 Validation Accuracy: 0.577600
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.7860 Validation Accuracy: 0.574400
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.7048 Validation Accuracy: 0.578400
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.6709 Validation Accuracy: 0.573400
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.8169 Validation Accuracy: 0.579000
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.7730 Validation Accuracy: 0.588000
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.7651 Validation Accuracy: 0.579400
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.7042 Validation Accuracy: 0.575200
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.6905 Validation Accuracy: 0.580400
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.8072 Validation Accuracy: 0.578000
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.7954 Validation Accuracy: 0.581200
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.7933 Validation Accuracy: 0.578600
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.6985 Validation Accuracy: 0.581200
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.7085 Validation Accuracy: 0.579600
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.7880 Validation Accuracy: 0.586400
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.7795 Validation Accuracy: 0.587800
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.7486 Validation Accuracy: 0.585000
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.6725 Validation Accuracy: 0.580400
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.6956 Validation Accuracy: 0.584600
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.7965 Validation Accuracy: 0.577400
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.7656 Validation Accuracy: 0.590200
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.7440 Validation Accuracy: 0.582200
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.6839 Validation Accuracy: 0.582000
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.7153 Validation Accuracy: 0.583200
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.7906 Validation Accuracy: 0.581200
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.7411 Validation Accuracy: 0.585200
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.7641 Validation Accuracy: 0.583400
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.6481 Validation Accuracy: 0.577600
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.7096 Validation Accuracy: 0.580600
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.8231 Validation Accuracy: 0.575000
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.7722 Validation Accuracy: 0.585200
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.7520 Validation Accuracy: 0.576800
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.6823 Validation Accuracy: 0.582200
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.7273 Validation Accuracy: 0.581600
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.8021 Validation Accuracy: 0.580000
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.7461 Validation Accuracy: 0.590600
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.7176 Validation Accuracy: 0.579400
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.6508 Validation Accuracy: 0.583800
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.6742 Validation Accuracy: 0.583200
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.7886 Validation Accuracy: 0.582400
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.7724 Validation Accuracy: 0.588000
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.7570 Validation Accuracy: 0.580600
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.6462 Validation Accuracy: 0.585400
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.6992 Validation Accuracy: 0.584000
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.7924 Validation Accuracy: 0.579600
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.7440 Validation Accuracy: 0.588400
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.7276 Validation Accuracy: 0.583400
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.6396 Validation Accuracy: 0.581800
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.6951 Validation Accuracy: 0.582400
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.7593 Validation Accuracy: 0.578600
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.7779 Validation Accuracy: 0.584800
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.7248 Validation Accuracy: 0.574600
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.6642 Validation Accuracy: 0.586600
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.6976 Validation Accuracy: 0.584400
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.7602 Validation Accuracy: 0.582000
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.7634 Validation Accuracy: 0.590400
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.7269 Validation Accuracy: 0.586400
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.6696 Validation Accuracy: 0.577200
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.6898 Validation Accuracy: 0.586400
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.7592 Validation Accuracy: 0.582200

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.5865234375

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
